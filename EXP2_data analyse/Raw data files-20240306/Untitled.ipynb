# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
Materials=pd.read_excel('modulus.xlsx',sheet_name="Materials")
Polymers=pd.read_excel('modulus.xlsx',sheet_name="Polymers")

# %%
Materials
# Out:
#    Sample   modulus(Pa)  modulus(KPa)
# 0      M1  2.853729e+05    285.372912
# 1      M2  5.941447e+05    594.144705
# 2      M3  5.396478e+05    539.647836
# 3      M4  1.454393e+06   1454.393351
# 4      M5  1.662016e+06   1662.016291
# 5      M6  3.478405e+05    347.840532
# 6      M7  5.316728e+05    531.672751
# 7      M8  1.559454e+06   1559.453867
# 8      M9  1.583080e+06   1583.080181
# 9     M11  2.957174e+05    295.717418
# 10    M12  8.413402e+05    841.340214
# 11    M13  1.505612e+06   1505.612296
# 12    M14  2.367432e+06   2367.432004
# 13    M18  1.801585e+06   1801.584538
# 14    M20  2.085513e+06   2085.512822
# 15    M21  6.561217e+05    656.121711
# 16    M22  5.177962e+05    517.796182
# 17    M23  1.414136e+06   1414.136073
# 18    M24  1.371300e+06   1371.300127
# 19    M26  1.852307e+06   1852.307282
# 20    M27  4.090864e+05    409.086431
# 21    M28  7.508043e+05    750.804284
# 22    M29  1.038260e+06   1038.260325
# 23    M30  1.976432e+06   1976.432110
# ...

# %%
print('Mean',np.round(np.mean(Materials['modulus(KPa)']),decimals=2))
print('median',np.round(np.median(Materials['modulus(KPa)']),decimals=2))
print('variance',np.round(np.var(Materials['modulus(KPa)']),decimals=2))
print('Standard deviation',np.round(np.std(Materials['modulus(KPa)']),decimals=2))
print("Standard error",np.round(np.std(Materials['modulus(KPa)'],ddof=1)/np.sqrt(np.size(Materials['modulus(KPa)'])),decimals=2))
print('Confidence interval',"[",np.round(np.mean(Materials['modulus(KPa)'])-1.96*np.std(Materials['modulus(KPa)'],ddof=1)/np.sqrt(np.size(Materials['modulus(KPa)']))
                                         ,decimals=2),",",
      np.round(np.mean(Materials['modulus(KPa)'])+1.96*np.std(Materials['modulus(KPa)'],ddof=1)/np.sqrt(np.size(Materials['modulus(KPa)'])),decimals=2),']')
# Out:
# Mean 1172.5
# median 1204.78
# variance 397681.91
# Standard deviation 630.62
# Standard error 113.26
# Confidence interval [ 950.51 , 1394.5 ]

# %%
Polymers
# Out:
#         Sample   modulus(Pa)  modulus(KPa)
# 0           P1  3.809380e+05    380.937971
# 1           P3  1.126706e+06   1126.705933
# 2           P4  2.417906e+05    241.790641
# 3           P5  1.808084e+06   1808.083708
# 4           P7  6.327259e+05    632.725928
# 5           P8  1.558095e+06   1558.095149
# 6          P14  1.764296e+06   1764.295561
# 7          P16  3.396119e+05    339.611850
# 8          P17  1.311000e+06   1311.000459
# 9          P18  2.211201e+06   2211.200854
# 10         P19  1.460212e+06   1460.211687
# 11         P21  3.624576e+05    362.457582
# 12         P23  2.158884e+06   2158.883711
# 13         P25  1.451744e+06   1451.744234
# 14         P26  3.759937e+05    375.993738
# 15         P28  2.114400e+06   2114.399966
# 16         P29  1.882791e+06   1882.791197
# 17         P34  1.480507e+06   1480.506676
# 18         P37  9.283613e+05    928.361334
# 19         P38  1.672296e+06   1672.295729
# 20         P41  3.719106e+05    371.910604
# ...

# %%
print('Mean',np.round(np.mean(Polymers['modulus(KPa)']),decimals=2))
print('median',np.round(np.median(Polymers['modulus(KPa)']),decimals=2))
print('Standard deviation',np.round(np.std(Polymers['modulus(KPa)']),decimals=2))
print("Standard error",np.round(np.std(Polymers['modulus(KPa)'],ddof=1)/np.sqrt(np.size(Polymers['modulus(KPa)'])),decimals=2))
print('Confidence interval',
      "[",np.round(np.mean(Polymers['modulus(KPa)'])-1.96*np.std(Polymers['modulus(KPa)'],ddof=1)/np.sqrt(np.size(Polymers['modulus(KPa)']))
        ,decimals=2),",",np.round(np.mean(Polymers['modulus(KPa)'])+1.96*np.std(Polymers['modulus(KPa)'],ddof=1)/np.sqrt(np.size(Polymers['modulus(KPa)'])),decimals=2),']')
# Out:
# Mean 1213.35
# median 1381.37
# Standard deviation 711.81
# Standard error 132.18
# Confidence interval [ 954.28 , 1472.42 ]

# %%
hist1,bin_edge1=np.histogram(Materials['modulus(KPa)'],bins=11,
                            range=(np.min(Materials['modulus(KPa)']),np.max(Materials['modulus(KPa)'])))
fig1,ax1=plt.subplots()
ax1_twin=ax1.twinx()
ax1.hist(bin_edge1[:-1],bin_edge1,weights=hist1,facecolor='blue')
ax1.set_xlabel('Modulus(KPa)')
ax1.set_ylabel('Frequncy')
ax1_twin.set_ylabel('Probability')
mu=Materials['modulus(KPa)'].mean()
sigma=Materials['modulus(KPa)'].std()
x=np.linspace(Materials['modulus(KPa)'].min(),Materials['modulus(KPa)'].max(),100)
ndf=np.exp(-(x-mu)**2/(2*sigma**2))/(sigma*np.sqrt(2*np.pi))
ax1_twin.plot(x,ndf,'r-',label="PDF")
ax1_twin.legend(loc='upper right')
plt.tight_layout()
plt.grid(True)
plt.title("The distribution of Material's group")
plt.show()

# %%
stats.probplot(Materials['modulus(KPa)'], dist="norm", plot=plt)
plt.title('Q-Q Plot')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.grid(True)
plt.show()

# %%
hist2,bin_edge2=np.histogram(Polymers['modulus(KPa)'],bins=11,
                            range=(np.min(Polymers['modulus(KPa)']),np.max(Polymers['modulus(KPa)'])))
fig2,ax2=plt.subplots()
ax2_twin=ax2.twinx()
ax2.hist(bin_edge2[:-1],bin_edge2,weights=hist2,facecolor='red')
ax2.set_xlabel('Modulus(KPa)')
ax2.set_ylabel('Frequency')
ax2_twin.set_ylabel('Probability')
mu=Polymers['modulus(KPa)'].mean()
sigma=Polymers['modulus(KPa)'].std()
x=np.linspace(Polymers['modulus(KPa)'].min(),Polymers['modulus(KPa)'].max(),100)
ndf=np.exp(-(x-mu)**2/(2*sigma**2))/(sigma*np.sqrt(2*np.pi))
ax2_twin.plot(x,ndf,'b-',label='PDF')
ax2_twin.legend(loc='upper right')
plt.tight_layout()
plt.grid(True)
plt.title("The distribution of Polymer's group")
plt.show()

# %%
stats.probplot(Polymers['modulus(KPa)'], dist="norm", plot=plt)
plt.title('Q-Q Plot')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.grid(True)
plt.show()

# %%
#Calculate the t-value
def t_value(x,y):
    t=(np.mean(x)-np.mean(y))/np.sqrt((np.std(x,ddof=1)**2)/np.size(x)+(np.std(y,ddof=1)**2)/np.size(y))
    return t

# %%
t_value(Materials['modulus(KPa)'],Polymers['modulus(KPa)'])
# Out:
# -0.23464008851286788

# %%
modified_m=pd.read_excel('modified material & polymer.xlsx',sheet_name='Sheet1')
modified_p=pd.read_excel('modified material & polymer.xlsx',sheet_name='Sheet2')
# Out:
#   material   modulus(Pa)  modulus(KPa)
# 0       MA  1.040333e+05    104.033259
# 1       MB  2.905249e+05    290.524942
# 2       MC  2.420104e+06   2420.103882
# 3       MD  2.865537e+06   2865.537249

# %%
print('Mean',np.round(np.mean(modified_p['modulus(KPa)']),decimals=2))
print('median',np.round(np.median(modified_p['modulus(KPa)']),decimals=2))
print('variance',np.round(np.var(modified_p['modulus(KPa)']),decimals=2))
print('Standard deviation',np.round(np.std(modified_p['modulus(KPa)']),decimals=2))
print("Standard error",np.round(np.std(modified_p['modulus(KPa)'],ddof=1)/np.sqrt(np.size(modified_m['modulus(KPa)'])),decimals=2))
# Out:
# Mean 301.5
# median 288.31
# variance 5488.43
# Standard deviation 74.08
# Standard error 42.77

# %%
print(np.sum(stats.rankdata(modified_m['modulus(KPa)'])))
print(np.sum(stats.rankdata(Materials['modulus(KPa)'])))
# Out:
# 10.0
# 528.0

# %%
def U(x,y):
    U=np.size(x)*np.size(y)+np.size(x)*np.size(x)-np.sum(stats.rankdata(x))
    return U

# %%
U(modified_m['modulus(KPa)'],Materials['modulus(KPa)'])
# Out:
# 134.0

# %%
hist3,bin_edge3=np.histogram(modified_m['modulus(KPa)'],bins=11,
                            range=(np.min(modified_m['modulus(KPa)']),np.max(modified_m['modulus(KPa)'])))
fig3,ax3=plt.subplots()
ax3_twin=ax3.twinx()
ax3.hist(bin_edge3[:-1],bin_edge3,weights=hist3,facecolor='blue', alpha=0.5)
ax3.set_xlabel('Modulus(KPa)')
ax3.set_ylabel('Frenqucy')
ax3_twin.set_ylabel('Probability')
mu=modified_m['modulus(KPa)'].mean()
sigma=modified_m['modulus(KPa)'].std()
x=np.linspace(modified_m['modulus(KPa)'].min(),modified_m['modulus(KPa)'].max(),100)
ndf=np.exp(-(x-mu)**2/(2*sigma**2))/(sigma*np.sqrt(2*np.pi))
ax3_twin.plot(x, ndf, 'r-', label='PDF')
ax3_twin.legend(loc='upper right')
plt.tight_layout()
plt.grid(True)
plt.title("The distribution of modified Material's group")
plt.show()

# %%
stats.probplot(modified_m['modulus(KPa)'], dist="norm", plot=plt)
plt.title('Q-Q Plot')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.grid(True)
plt.show()

# %%
hist4,bin_edge4=np.histogram(modified_p['modulus(KPa)'],bins=4,
                            range=(np.min(modified_p['modulus(KPa)']),np.max(modified_p['modulus(KPa)'])))
fig4,ax4=plt.subplots()
ax4_twin=ax4.twinx()
ax4.hist(bin_edge4[:-1],bin_edge4,weights=hist4,facecolor='red',alpha=0.5)
ax4.set_xlabel('Modulus(KPa)')
ax4_twin.set_ylabel('Frequency')
ax4.set_ylabel('Probability')
mu=modified_p['modulus(KPa)'].mean()
sigma=modified_p['modulus(KPa)'].std()
x=np.linspace(modified_p['modulus(KPa)'].min(),modified_p['modulus(KPa)'].max(),100)
ndf=np.exp(-(x-mu)**2/(2*sigma**2))/(sigma*np.sqrt(2*np.pi))
ax4_twin.plot(x, ndf, 'b-', label='PDF')
ax4_twin.legend(loc='upper right')
plt.tight_layout()
plt.grid(True)
plt.title("The distribution of modified Polymer's group")
plt.show()

# %%
stats.probplot(modified_p['modulus(KPa)'], dist="norm", plot=plt)
plt.title('Q-Q Plot')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.grid(True)
plt.show()
